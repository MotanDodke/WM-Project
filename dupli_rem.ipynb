# %%
import pandas as pd

# %%
df = pd.read_csv('washing machine.csv')

# %%
df
# Out:
#      Unnamed: 0                                               Name  Rating  \
# 0             0  FOXSKY 7.5 kg Semi Automatic Top Load Washing ...     4.1
# 1             1  Intex 7.5 kg With Lint Filter, Buzzer, Castor ...     4.3
# 2             2  Intex 6.5 kg With Air Dry Technology, Wave Pul...     4.3
# 3             3  LG 7 kg 5 Star with Wind Jet Dry, Collar Scrub...     4.4
# 4             4  Haier 6.5 kg 5 Star Oceanus Wave Drum Washing ...     4.3
# ..          ...                                                ...     ...
# 955         955  realme TechLife 7 kg 5 Star rating Semi Automa...     4.2
# 956         956  Panasonic 6.5 kg Semi Automatic Top Load Washi...     4.3
# 957         957  Thomson 8 kg PureWash Fully Automatic Top Load...     4.0
# 958         958  SAMSUNG 8 kg 5 star, Ecobubble, Digital Invert...     4.3
# 959         959  Thomson 7.5 kg 5 Star Aqua Magic Semi Automati...     4.0
#
#     Current Price Original Price Discount  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0
